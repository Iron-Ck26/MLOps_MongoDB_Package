# %%
import pandas as pd

# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://Iron_Ck:55252555_Ck@mlops-mongodb-cluster1.etxtatl.mongodb.net/?retryWrites=true&w=majority&appName=MLOps-MongoDB-Cluster1"
# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# here is my mongodb pacagess and key and password
# Out:
# SSL handshake failed: ac-dcusgdx-shard-00-02.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-dcusgdx-shard-00-00.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-dcusgdx-shard-00-01.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 664ef6905af2bd7e114cbcde, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-dcusgdx-shard-00-00.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-00.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-dcusgdx-shard-00-01.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-01.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-dcusgdx-shard-00-02.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-02.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>]>

# %%
database= client["youtubcomunity"] # this is my database name youtubcomunity

# %%
collection= database["session"]  #this is collection name which is in the database

# %%
data = {
    "coursename":"genai",
    "instrutorname":"chakrapani",
    "modeofsession":"english", 
}

# this is data in collection in from key and value from

# %%
data
# Out:
# {'coursename': 'genai',
#  'instrutorname': 'chakrapani',
#  'modeofsession': 'english',
#  '_id': ObjectId('664ef6d05af2bd7e114cbcdf')}

# %%
collection.insert_one(data)

# this is for store the data inside the collection
# now this database is avalable in mongodb Atlas
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 collection.insert_one(data)
#       3 # this is for store the data inside the collection
#       4 # now this database is avalable in mongodb Atlas
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
#     664         session=session,
#     665         comment=comment,
#     666     ),
#     667     write_concern.acknowledged,
#     668 )
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\collection.py:598, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     586     result = conn.command(
#     587         self.__database.name,
#     588         command,
#    (...)
#     593         retryable_write=retryable_write,
#     594     )
#     596     _check_write_command_response(result)
# --> 598 self.__database.client._retryable_write(
#     599     acknowledged, _insert_command, session, operation=_Op.INSERT
#     600 )
#     602 if not isinstance(doc, RawBSONDocument):
#     603     return doc.get("_id")
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:2450, in _ClientConnectionRetryable._write(self)
#    2448 max_wire_version = 0
#    2449 is_mongos = False
# -> 2450 self._server = self._get_server()
#    2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1316, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1314             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1315     else:
# -> 1316         server = topology.select_server(
#    1317             server_selector,
#    1318             operation,
#    1319             deprioritized_servers=deprioritized_servers,
#    1320             operation_id=operation_id,
#    1321         )
#    1322     return server
#    1323 except PyMongoError as exc:
#    1324     # Server selection errors in a transaction are transient.
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:369, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     359 def select_server(
#     360     self,
#     361     selector: Callable[[Selection], Selection],
#    (...)
#     366     operation_id: Optional[int] = None,
#     367 ) -> Server:
#     368     """Like select_servers, but choose a random server if several match."""
# --> 369     server = self._select_server(
#     370         selector,
#     371         operation,
#     372         server_selection_timeout,
#     373         address,
#     374         deprioritized_servers,
#     375         operation_id=operation_id,
#     376     )
#     377     if _csot.get_timeout():
#     378         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:347, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     338 def _select_server(
#     339     self,
#     340     selector: Callable[[Selection], Selection],
#    (...)
#     345     operation_id: Optional[int] = None,
#     346 ) -> Server:
# --> 347     servers = self.select_servers(
#     348         selector, operation, server_selection_timeout, address, operation_id
#     349     )
#     350     servers = _filter_servers(servers, deprioritized_servers)
#     351     if len(servers) == 1:
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:254, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     251     server_timeout = server_selection_timeout
#     253 with self._lock:
# --> 254     server_descriptions = self._select_servers_loop(
#     255         selector, server_timeout, operation, operation_id, address
#     256     )
#     258     return [
#     259         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     260     ]
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:304, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     293     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     294         _debug_log(
#     295             _SERVER_SELECTION_LOGGER,
#     296             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     302             failure=self._error_message(selector),
#     303         )
# --> 304     raise ServerSelectionTimeoutError(
#     305         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     306     )
#     308 if not logged_waiting:
#     309     _info_log(
#     310         _SERVER_SELECTION_LOGGER,
#     311         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     317         remainingTimeMS=int(end_time - time.monotonic()),
#     318     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-dcusgdx-shard-00-02.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-dcusgdx-shard-00-00.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-dcusgdx-shard-00-01.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 664ef6905af2bd7e114cbcde, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-dcusgdx-shard-00-00.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-00.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-dcusgdx-shard-00-01.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-01.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-dcusgdx-shard-00-02.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-02.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>]>

# %%
all_record= collection.find()

# call find for get complit data and it giv as oject

# %%
for record in all_record:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for record in all_record:
#       2     print(record)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
#    1141         )
#    1142     q = self._query_class(
#    1143         self.__query_flags,
#    1144         self.__collection.database.name,
#    (...)
#    1158         self.__exhaust,
#    1159     )
# -> 1160     self.__send_message(q)
#    1161 elif self.__id:  # Get More
#    1162     if self.__limit:
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\cursor.py:1039, in Cursor.__send_message(self, operation)
#    1036     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1038 try:
# -> 1039     response = client._run_operation(
#    1040         operation, self._unpack_response, address=self.__address
#    1041     )
#    1042 except OperationFailure as exc:
#    1043     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1044         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1425, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1415     operation.reset()  # Reset op in case of retry.
#    1416     return server.run_operation(
#    1417         conn,
#    1418         operation,
#    (...)
#    1422         self,
#    1423     )
# -> 1425 return self._retryable_read(
#    1426     _cmd,
#    1427     operation.read_preference,
#    1428     operation.session,
#    1429     address=address,
#    1430     retryable=isinstance(operation, message._Query),
#    1431     operation=operation.name,
#    1432 )
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1534, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1529 # Ensure that the client supports retrying on reads and there is no session in
#    1530 # transaction, otherwise, we will not support retry behavior for this call.
#    1531 retryable = bool(
#    1532     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1533 )
# -> 1534 return self._retry_internal(
#    1535     func,
#    1536     session,
#    1537     None,
#    1538     operation,
#    1539     is_read=True,
#    1540     address=address,
#    1541     read_pref=read_pref,
#    1542     retryable=retryable,
#    1543     operation_id=operation_id,
#    1544 )
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:2477, in _ClientConnectionRetryable._read(self)
#    2472 def _read(self) -> T:
#    2473     """Wrapper method for read-type retryable client executions
#    2474
#    2475     :return: Output for func()'s call
#    2476     """
# -> 2477     self._server = self._get_server()
#    2478     assert self._read_pref is not None, "Read Preference required on read calls"
#    2479     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2480         conn,
#    2481         read_pref,
#    2482     ):
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\mongo_client.py:1316, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1314             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1315     else:
# -> 1316         server = topology.select_server(
#    1317             server_selector,
#    1318             operation,
#    1319             deprioritized_servers=deprioritized_servers,
#    1320             operation_id=operation_id,
#    1321         )
#    1322     return server
#    1323 except PyMongoError as exc:
#    1324     # Server selection errors in a transaction are transient.
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:369, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     359 def select_server(
#     360     self,
#     361     selector: Callable[[Selection], Selection],
#    (...)
#     366     operation_id: Optional[int] = None,
#     367 ) -> Server:
#     368     """Like select_servers, but choose a random server if several match."""
# --> 369     server = self._select_server(
#     370         selector,
#     371         operation,
#     372         server_selection_timeout,
#     373         address,
#     374         deprioritized_servers,
#     375         operation_id=operation_id,
#     376     )
#     377     if _csot.get_timeout():
#     378         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:347, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     338 def _select_server(
#     339     self,
#     340     selector: Callable[[Selection], Selection],
#    (...)
#     345     operation_id: Optional[int] = None,
#     346 ) -> Server:
# --> 347     servers = self.select_servers(
#     348         selector, operation, server_selection_timeout, address, operation_id
#     349     )
#     350     servers = _filter_servers(servers, deprioritized_servers)
#     351     if len(servers) == 1:
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:254, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     251     server_timeout = server_selection_timeout
#     253 with self._lock:
# --> 254     server_descriptions = self._select_servers_loop(
#     255         selector, server_timeout, operation, operation_id, address
#     256     )
#     258     return [
#     259         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     260     ]
#
# File c:\Users\ChakrapaniWaghmode\.conda\envs\MLOps_test\Lib\site-packages\pymongo\topology.py:304, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     293     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     294         _debug_log(
#     295             _SERVER_SELECTION_LOGGER,
#     296             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     302             failure=self._error_message(selector),
#     303         )
# --> 304     raise ServerSelectionTimeoutError(
#     305         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     306     )
#     308 if not logged_waiting:
#     309     _info_log(
#     310         _SERVER_SELECTION_LOGGER,
#     311         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     317         remainingTimeMS=int(end_time - time.monotonic()),
#     318     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-dcusgdx-shard-00-02.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-dcusgdx-shard-00-00.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-dcusgdx-shard-00-01.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 664ef6905af2bd7e114cbcde, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-dcusgdx-shard-00-00.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-00.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-dcusgdx-shard-00-01.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-01.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-dcusgdx-shard-00-02.etxtatl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-dcusgdx-shard-00-02.etxtatl.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>]>

# %%
collection.insert_many(
    [
        {

    "coursename":"genai",
    "instrutorname":"Iron_Ck",
    "modeofsession":"english"
},

{

    "coursename":"mlops",
    "instrutorname":"chakrapani",
    "modeofsession":"english&hindi"
}
        
    ]
)
# Out:
# InsertManyResult([ObjectId('664dd6b1007ceccf99a10f93'), ObjectId('664dd6b1007ceccf99a10f94')], acknowledged=True)

# %%
class mongodb_operation:

    def __init__(self,client_url: str, database_name: str, collection_name: str=None):
        self.client_url=client_url
        self.database_name=database_name
        self.collection_name=collection_name

    def create_client(self):        # Create client which collect data from mongodb
        client=MongoClient(self.client_url)
        return client


    def create_database(self):         #create database in maongodb
        client=self.create_client()
        database=client[self.database_name]     # which store in client
        return database
        
    def create_collection(self,collection=None):    # collection is an data
        database=self.create_database()
        collection=database[collection]         # which store in database
        return collection

    def insert_record(self,record:dict,collection_name:str):
        if type(record)==list:
            for data in record:
                if type(data)!= dict:     # data is store in from of document(dict) in list
                    raise TypeError("record must be in the dict")
            collection=self.create_collection(collection_name)  # here store data in collection
            collection.insert_many(record)              # store multipan record or collections
        elif type(record)==dict:
            collection=self.create_collection(collection_name)
            collection.insert_one(record)       # # store single (one) record or collections

    def bulk_insert(self,datafile:str,collection_name:str=None):        # call file or data file
        self.path=datafile

        if self.path.endswith('.csv'):      # if file path is csv format
            data=pd.read_csv(self.path,encoding='utf-8')

        elif self.path.endswith('.xlsx'):   # if file in excle format 
            data=pd.read_excel(self.path,encoding='utf-8')
        # you can put other file path sa will just change file format or extention on csv or xlsx place   
        
        datajson=json.loads(data.to_json(orient='record'))  # convert data in jsion format
        collection=self.create_collection()
        collection.insert_many(datajson)


# this code you can publish as from of pacasses

# %%
#call the mongodb connection 
client_url =  "mongodb+srv://Iron_Ck:55252555_Ck@mlops-mongodb-cluster1.etxtatl.mongodb.net/?retryWrites=true&w=majority&appName=MLOps-MongoDB-Cluster1"  # I have created a demo connection for you to understand. You can use your own.
database = "mynewdatabase"
collection_name = "myoldcolumn"

# %%
mongo=mongodb_operation(client_url,database,collection_name)  # create collection in mongodb

# %%
mongo.insert_record({"name":"chakrapani","designation":"data scientist","salary":"10k"},collection_name)
# Insert the record in collection in mongodb
# single record

# %%
mongo.insert_record([{"name":"sunny","designation":"data scientist","salary":"10k"},
{"name":"Iron_Ck","designation":"sr. data scientist","salary":"150k"},
{"name":"Sohan","designation":"lead data scientist","salary":"70k"}
],collection_name)

# Multipan record
